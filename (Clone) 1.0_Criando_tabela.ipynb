# %% [markdown]
# ### Criar Catalog

# %%
# %sql
CREATE CATALOG IF NOT EXISTS meu_catalog
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
spark.sql(f"""
CREATE CATALOG IF NOT EXISTS meu_catalog
""")

# %% [markdown]
# ### Criar Schema

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS meu_catalog.meu_schema

# %%
spark.sql(f"""
CREATE SCHEMA IF NOT EXISTS meu_catalog.meu_schema
""")

# %% [markdown]
# ### Criar Tabela

# %%
# %sql
CREATE TABLE IF NOT EXISTS meu_catalog.meu_schema.tabela (
    id BIGINT,
    nome STRING,
    email STRING,
    dt_cadastro TIMESTAMP);

# %%
spark.sql(f"""
CREATE TABLE IF NOT EXISTS  meu_catalog.meu_schema.tabela (
    id BIGINT,
    nome STRING,
    email STRING,
    dt_cadastro TIMESTAMP
)
""")

# %%
### Criar tabela a partir de DataFrame
df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("meu_catalog.meu_schema.tabela")

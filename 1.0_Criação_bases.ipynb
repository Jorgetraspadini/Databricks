# %% [markdown]
# ### Criar Catalog

# %%
# %sql
CREATE CATALOG IF NOT EXISTS operacoes

# %% [markdown]
# ### Criar Schema

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS operacoes.servicos

# %% [markdown]
# ### Criar Tabela

# %%
df = spark.read.option("header", "true").option("delimiter", ";").csv("/Workspace/Users/jorgeeduardobt@gmail.com/Databricks/arquivos/cotacao_usd.csv")

df.write.format("delta").mode("overwrite").saveAsTable("operacoes.servicos.cotacao")

# %%
df = spark.read.option("header", "true").option("delimiter", ",").csv("/Workspace/Users/jorgeeduardobt@gmail.com/Databricks/arquivos/Clientes.csv")

df.write.format("delta").mode("overwrite").saveAsTable("operacoes.servicos.cliente")

# %%
df = spark.read.option("header", "true").option("delimiter", ",").csv("/Workspace/Users/jorgeeduardobt@gmail.com/Databricks/arquivos/Produtos.csv")

df.write.format("delta").mode("overwrite").saveAsTable("operacoes.servicos.produtos")

# %%
df = spark.read.option("header", "true").option("delimiter", ",").csv("/Workspace/Users/jorgeeduardobt@gmail.com/Databricks/arquivos/Transacoes.csv")

df.write.format("delta").mode("overwrite").saveAsTable("operacoes.servicos.transacoes")

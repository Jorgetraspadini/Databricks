# %%
df = (spark.read
         .option("header", "true")
         .option("inferSchema", "true")
         .option("sep", ";")
         .csv("/Workspace/Users/jorgeeduardobt@gmail.com/Databricks/arquivos/tabela_produtos.csv"))
display(df)
